# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_df = pd.read_csv("we_fn_use_c_marketing_customer_value_analysis.csv")

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# ### Renaming Columns & changing

# %%
customer_df.columns = customer_df.columns.str.lower()
customer_df.columns = customer_df.columns.str.replace(" ", "_")
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
customer_df['effective_to_date'] = customer_df['effective_to_date'].astype('datetime64[ns]')

# %% [markdown]
# ### Splitting Categorial and Numerical
# ##### After splitting the data, I realise it is correctly split, and the dates are put into categorical, how I want it. I can now change the dates to datetime format

# %%
customer_df_NUM = customer_df.select_dtypes(include = "number")
customer_df_CAT = customer_df.select_dtypes(exclude = "number")

# %%
customer_df_CAT
# Out:
#      customer       state response  coverage education effective_to_date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1     QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
customer_df_NUM
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# ### Plotting Correlation Matrix
#
# After putting in the correlation heatmap, I realise a lot of the numerical variables are not correlated. I will keep all the columns for now

# %%
correlation_matrix_num = customer_df_NUM.corr().apply(lambda x: round(x,2))
correlation_matrix_num
# Out:
#                                customer_lifetime_value  income  \
# customer_lifetime_value                           1.00    0.02
# income                                            0.02    1.00
# monthly_premium_auto                              0.40   -0.02
# months_since_last_claim                           0.01   -0.03
# months_since_policy_inception                     0.01   -0.00
# number_of_open_complaints                        -0.04    0.01
# number_of_policies                                0.02   -0.01
# total_claim_amount                                0.23   -0.36
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                        0.40                     0.01
# income                                        -0.02                    -0.03
# monthly_premium_auto                           1.00                     0.01
# months_since_last_claim                        0.01                     1.00
# ...

# %%
correlation_matrix_num = customer_df_NUM.corr().apply(lambda x: round(x,2))
sns.heatmap(correlation_matrix_num, cmap = "coolwarm", annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Plotting the distribution Plots for continuos variables

# %%
for i in customer_df_NUM.columns:
    sns.distplot(customer_df_NUM[i])
    plt.show()
# Out:
# /Users/rikibravo/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/rikibravo/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Why are we deleting customer_id
# We need to delete it because it is a unique value for each row that is completely independent to both the target variable and the other columns. Therefore it is just filling space and confusing the model. We should delete it

# %%
customer_df_CAT = customer_df_CAT.drop(columns = "customer")

# %%
customer_df_CAT
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor        2011-02-24
# 1        Arizona       No  Extended  Bachelor        2011-01-31
# 2         Nevada       No   Premium  Bachelor        2011-02-19
# 3     California       No     Basic  Bachelor        2011-01-20
# 4     Washington       No     Basic  Bachelor        2011-02-03
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor        2011-02-10
# 9130  California      Yes  Extended   College        2011-02-12
# 9131  California       No  Extended  Bachelor        2011-02-06
# 9132  California       No  Extended   College        2011-02-03
# 9133  California       No  Extended   College        2011-02-14
#
#      employmentstatus gender location_code marital_status     policy_type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# ...

# %% [markdown]
# For categorial variables I will use a countplot

# %%
for i in customer_df_CAT.columns:
    sns.countplot(x=i, data=customer_df_CAT)
    plt.show()

# %% [markdown]
# ### Looking for Outliers
#
# Customer_lifetime_value :  it has a lot of outliers, and we have options of Removing Outliers or using the Box Cox transformation to deal with them
#
# Same with monthly premium_auto and total claim amount

# %%
for i in customer_df_NUM.columns:
    sns.boxplot(customer_df_NUM[i])
    plt.show()
# Out:
# /Users/rikibravo/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/rikibravo/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ### Checking for Nans
# There are no empty or nan values in the numerical and
# there are no empty or nan values in the categorical

# %%
customer_df_NUM = customer_df_NUM.replace("",np.nan)
customer_df_NUM = customer_df_NUM.replace(" ",np.nan)

# %%
nan= customer_df_NUM.isna().sum()
print(nan[nan > 0])
# Out:
# Series([], dtype: int64)

# %%
customer_df_CAT = customer_df_CAT.replace("",np.nan)
customer_df_CAT = customer_df_CAT.replace(" ",np.nan)

# %%
nan_cat= customer_df_CAT.isna().sum()
print(nan_cat[nan_cat > 0])
# Out:
# Series([], dtype: int64)
